# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("adult.csv")
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# 0                      ?  Not-in-family  White  Female             0
# 1        Exec-managerial  Not-in-family  White  Female             0
# 2                      ?      Unmarried  Black  Female             0
# 3      Machine-op-inspct      Unmarried  White  Female             0
# 4         Prof-specialty      Own-child  White  Female             0
# ...                  ...            ...    ...     ...           ...
# 32556    Protective-serv  Not-in-family  White    Male             0
# 32557       Tech-support           Wife  White  Female             0
# 32558  Machine-op-inspct        Husband  White    Male             0
# 32559       Adm-clerical      Unmarried  White  Female             0
# 32560       Adm-clerical      Own-child  White    Male             0
#
#        capital.loss  hours.per.week native.country income
# 0              4356              40  United-States  <=50K
# 1              4356              18  United-States  <=50K
# 2              4356              40  United-States  <=50K
# 3              3900              40  United-States  <=50K
# 4              3900              40  United-States  <=50K
# ...             ...             ...            ...    ...
# 32556             0              40  United-States  <=50K
# 32557             0              38  United-States  <=50K
# 32558             0              40  United-States   >50K
# 32559             0              40  United-States  <=50K
# 32560             0              20  United-States  <=50K
#
# [32561 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.head(10)
# Out:
#    age    workclass  fnlwgt     education  education.num marital.status  \
# 0   90            ?   77053       HS-grad              9        Widowed
# 1   82      Private  132870       HS-grad              9        Widowed
# 2   66            ?  186061  Some-college             10        Widowed
# 3   54      Private  140359       7th-8th              4       Divorced
# 4   41      Private  264663  Some-college             10      Separated
# 5   34      Private  216864       HS-grad              9       Divorced
# 6   38      Private  150601          10th              6      Separated
# 7   74    State-gov   88638     Doctorate             16  Never-married
# 8   68  Federal-gov  422013       HS-grad              9       Divorced
# 9   41      Private   70037  Some-college             10  Never-married
#
#           occupation    relationship   race     sex  capital.gain  \
# 0                  ?   Not-in-family  White  Female             0
# 1    Exec-managerial   Not-in-family  White  Female             0
# 2                  ?       Unmarried  Black  Female             0
# 3  Machine-op-inspct       Unmarried  White  Female             0
# 4     Prof-specialty       Own-child  White  Female             0
# 5      Other-service       Unmarried  White  Female             0
# 6       Adm-clerical       Unmarried  White    Male             0
# 7     Prof-specialty  Other-relative  White  Female             0
# 8     Prof-specialty   Not-in-family  White  Female             0
# 9       Craft-repair       Unmarried  White    Male             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K
# 5          3770              45  United-States  <=50K
# 6          3770              40  United-States  <=50K
# 7          3683              20  United-States   >50K
# 8          3683              40  United-States  <=50K
# 9          3004              60              ?   >50K

# %%
df.isnull().sum()

# Dataset showing null values as ?
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.replace("?",pd.NA,inplace=True)

# %%
df.head(5)
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90      <NA>   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66      <NA>  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0               <NA>  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2               <NA>      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
#Removing those columns that is not useful here.
df.drop(columns=["fnlwgt","education","capital.gain","capital.loss"],inplace=True)

# %%
df.head(10)
# Out:
#    age    workclass  education.num marital.status         occupation  \
# 0   90         <NA>              9        Widowed               <NA>
# 1   82      Private              9        Widowed    Exec-managerial
# 2   66         <NA>             10        Widowed               <NA>
# 3   54      Private              4       Divorced  Machine-op-inspct
# 4   41      Private             10      Separated     Prof-specialty
# 5   34      Private              9       Divorced      Other-service
# 6   38      Private              6      Separated       Adm-clerical
# 7   74    State-gov             16  Never-married     Prof-specialty
# 8   68  Federal-gov              9       Divorced     Prof-specialty
# 9   41      Private             10  Never-married       Craft-repair
#
#      relationship   race     sex  hours.per.week native.country income
# 0   Not-in-family  White  Female              40  United-States  <=50K
# 1   Not-in-family  White  Female              18  United-States  <=50K
# 2       Unmarried  Black  Female              40  United-States  <=50K
# 3       Unmarried  White  Female              40  United-States  <=50K
# 4       Own-child  White  Female              40  United-States  <=50K
# 5       Unmarried  White  Female              45  United-States  <=50K
# 6       Unmarried  White    Male              40  United-States  <=50K
# 7  Other-relative  White  Female              20  United-States   >50K
# 8   Not-in-family  White  Female              40  United-States  <=50K
# 9       Unmarried  White    Male              60           <NA>   >50K

# %%
# Replacing the names of columns

df.rename(columns={"education.num":"Education","marital.status":"Marital","occupation":"Job","hours.per.week":"Hours","native.country":"Country"},inplace=True)

# %%
df.head(10)
# Out:
#    age    workclass  Education        Marital                Job  \
# 0   90         <NA>          9        Widowed               <NA>
# 1   82      Private          9        Widowed    Exec-managerial
# 2   66         <NA>         10        Widowed               <NA>
# 3   54      Private          4       Divorced  Machine-op-inspct
# 4   41      Private         10      Separated     Prof-specialty
# 5   34      Private          9       Divorced      Other-service
# 6   38      Private          6      Separated       Adm-clerical
# 7   74    State-gov         16  Never-married     Prof-specialty
# 8   68  Federal-gov          9       Divorced     Prof-specialty
# 9   41      Private         10  Never-married       Craft-repair
#
#      relationship   race     sex  Hours        Country income
# 0   Not-in-family  White  Female     40  United-States  <=50K
# 1   Not-in-family  White  Female     18  United-States  <=50K
# 2       Unmarried  Black  Female     40  United-States  <=50K
# 3       Unmarried  White  Female     40  United-States  <=50K
# 4       Own-child  White  Female     40  United-States  <=50K
# 5       Unmarried  White  Female     45  United-States  <=50K
# 6       Unmarried  White    Male     40  United-States  <=50K
# 7  Other-relative  White  Female     20  United-States   >50K
# 8   Not-in-family  White  Female     40  United-States  <=50K
# 9       Unmarried  White    Male     60           <NA>   >50K

# %%
df.isnull().sum()
# Out:
# age                0
# workclass       1836
# Education          0
# Marital            0
# Job             1843
# relationship       0
# race               0
# sex                0
# Hours              0
# Country          583
# income             0
# dtype: int64

# %%
# Here we can drop null values
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# age             0
# workclass       0
# Education       0
# Marital         0
# Job             0
# relationship    0
# race            0
# sex             0
# Hours           0
# Country         0
# income          0
# dtype: int64

# %%
df["age"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df["workclass"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
# Here we can see Private showing majority workclass and Without pay showing nothing, so we can drop that.

df["workclass"].unique()
# Out:
# array(['Private', 'State-gov', 'Federal-gov', 'Self-emp-not-inc',
#        'Self-emp-inc', 'Local-gov', 'Without-pay'], dtype=object)

# %%
df = df[df["workclass"] != 'Without-pay']

# %%
df["workclass"].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df["Education"].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Most of the people having education till 9 and showning least education 1.


Marital_counts = df['Marital'].value_counts()
plt.figure(figsize=(10,7))
patches,texts, _ = plt.pie(Marital_counts, autopct='%1.1f%%')
plt.title('Marital Status Distribution')
plt.legend(patches, Marital_counts.index, title="Marital Status", loc="center left", bbox_to_anchor=(1,0,0.5,1))

plt.show()

# %%
df["Job"].value_counts()
# Out:
# Prof-specialty       4038
# Craft-repair         4029
# Exec-managerial      3992
# Adm-clerical         3718
# Sales                3584
# Other-service        3211
# Machine-op-inspct    1965
# Transport-moving     1571
# Handlers-cleaners    1349
# Farming-fishing       983
# Tech-support          912
# Protective-serv       644
# Priv-house-serv       143
# Armed-Forces            9
# Name: Job, dtype: int64

# %%
df["Job"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    age workclass  Education    Marital                Job   relationship  \
# 1   82   Private          9    Widowed    Exec-managerial  Not-in-family
# 3   54   Private          4   Divorced  Machine-op-inspct      Unmarried
# 4   41   Private         10  Separated     Prof-specialty      Own-child
# 5   34   Private          9   Divorced      Other-service      Unmarried
# 6   38   Private          6  Separated       Adm-clerical      Unmarried
#
#     race     sex  Hours        Country income
# 1  White  Female     18  United-States  <=50K
# 3  White  Female     40  United-States  <=50K
# 4  White  Female     40  United-States  <=50K
# 5  White  Female     45  United-States  <=50K
# 6  White    Male     40  United-States  <=50K

# %%
df["race"].value_counts()
# Out:
# White                 25921
# Black                  2816
# Asian-Pac-Islander      894
# Amer-Indian-Eskimo      286
# Other                   231
# Name: race, dtype: int64

# %%
df["relationship"].value_counts()
# Out:
# Husband           12459
# Not-in-family      7726
# Own-child          4461
# Unmarried          3210
# Wife               1403
# Other-relative      889
# Name: relationship, dtype: int64

# %%
df["relationship"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
#Checking relationship between work class and income
df.groupby("workclass").income.value_counts()
# Out:
# workclass         income
# Federal-gov       <=50K       578
#                   >50K        365
# Local-gov         <=50K      1458
#                   >50K        609
# Private           <=50K     17410
#                   >50K       4876
# Self-emp-inc      >50K        600
#                   <=50K       474
# Self-emp-not-inc  <=50K      1785
#                   >50K        714
# State-gov         <=50K       935
#                   >50K        344
# Name: income, dtype: int64

# %%
df.groupby("workclass").income.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='workclass,income'>

# %%
df.head()
# Out:
#    age workclass  Education    Marital                Job   relationship  \
# 1   82   Private          9    Widowed    Exec-managerial  Not-in-family
# 3   54   Private          4   Divorced  Machine-op-inspct      Unmarried
# 4   41   Private         10  Separated     Prof-specialty      Own-child
# 5   34   Private          9   Divorced      Other-service      Unmarried
# 6   38   Private          6  Separated       Adm-clerical      Unmarried
#
#     race     sex  Hours        Country income
# 1  White  Female     18  United-States  <=50K
# 3  White  Female     40  United-States  <=50K
# 4  White  Female     40  United-States  <=50K
# 5  White  Female     45  United-States  <=50K
# 6  White    Male     40  United-States  <=50K

# %%
#Checking relationship between work class and education
df.groupby("workclass").Education.value_counts()
# Out:
# workclass    Education
# Federal-gov  9            260
#              10           251
#              13           207
#              14            65
#              12            55
#                          ...
# State-gov    8             10
#              5              6
#              3              4
#              1              1
#              2              1
# Name: Education, Length: 92, dtype: int64

# %%
df.groupby("workclass").Education.value_counts().plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
# education vs income
df.groupby("income").Education.mean().reset_index().sort_values(by="income")
# Out:
#   income  Education
# 0  <=50K   9.629461
# 1   >50K  11.606420

# %%
df.race.value_counts().plot(kind="pie")# Most of the people showing white followed by black and Asian
# Out:
# <Axes: ylabel='race'>

# %%
# Marital status vs race
df.groupby("Marital").race.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Marital,race'>

# %%
df.head()
# Out:
#    age workclass  Education    Marital                Job   relationship  \
# 1   82   Private          9    Widowed    Exec-managerial  Not-in-family
# 3   54   Private          4   Divorced  Machine-op-inspct      Unmarried
# 4   41   Private         10  Separated     Prof-specialty      Own-child
# 5   34   Private          9   Divorced      Other-service      Unmarried
# 6   38   Private          6  Separated       Adm-clerical      Unmarried
#
#     race     sex  Hours        Country income
# 1  White  Female     18  United-States  <=50K
# 3  White  Female     40  United-States  <=50K
# 4  White  Female     40  United-States  <=50K
# 5  White  Female     45  United-States  <=50K
# 6  White    Male     40  United-States  <=50K

# %%
# Job vs hours
df.groupby("Job").Hours.mean().reset_index().sort_values(by="Hours")
# Out:
#                   Job      Hours
# 8     Priv-house-serv  32.797203
# 7       Other-service  34.599190
# 0        Adm-clerical  37.576116
# 5   Handlers-cleaners  37.873239
# 12       Tech-support  39.473684
# 1        Armed-Forces  40.666667
# 6   Machine-op-inspct  40.715013
# 11              Sales  40.763393
# 2        Craft-repair  42.298585
# 9      Prof-specialty  42.374938
# 10    Protective-serv  42.846273
# 13   Transport-moving  44.665818
# 3     Exec-managerial  44.966934
# 4     Farming-fishing  47.053917

# %%
# Farming-fishing showing highest no.of hours and Priv-house-serv showing least.
df.income.value_counts().plot(kind="bar")
# Majority of people earn less than 50k
# Out:
# <Axes: >

# %%
# Model building

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30148 entries, 1 to 32560
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           30148 non-null  int64
#  1   workclass     30148 non-null  object
#  2   Education     30148 non-null  int64
#  3   Marital       30148 non-null  object
#  4   Job           30148 non-null  object
#  5   relationship  30148 non-null  object
#  6   race          30148 non-null  object
#  7   sex           30148 non-null  object
#  8   Hours         30148 non-null  int64
#  9   Country       30148 non-null  object
#  10  income        30148 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 2.8+ MB

# %%
df.isnull().sum()
# Out:
# age             0
# workclass       0
# Education       0
# Marital         0
# Job             0
# relationship    0
# race            0
# sex             0
# Hours           0
# Country         0
# income          0
# dtype: int64

# %%
# For workclass using frequency encoding

location_freq = df["workclass"].value_counts(normalize=True).to_dict()
df['workclass_freq'] = df["workclass"].map(location_freq)

df.drop(columns=["workclass"], inplace=True)

# %%
df.head()
# Out:
#    age  Education    Marital                Job   relationship   race     sex  \
# 1   82          9    Widowed    Exec-managerial  Not-in-family  White  Female
# 3   54          4   Divorced  Machine-op-inspct      Unmarried  White  Female
# 4   41         10  Separated     Prof-specialty      Own-child  White  Female
# 5   34          9   Divorced      Other-service      Unmarried  White  Female
# 6   38          6  Separated       Adm-clerical      Unmarried  White    Male
#
#    Hours        Country income  workclass_freq
# 1     18  United-States  <=50K         0.73922
# 3     40  United-States  <=50K         0.73922
# 4     40  United-States  <=50K         0.73922
# 5     45  United-States  <=50K         0.73922
# 6     40  United-States  <=50K         0.73922

# %%
# For marital, using one hot encoding as there are less no. of unique values

df['Marital'] = df['Marital'].astype('category')
df = pd.get_dummies(df, columns=['Marital'], prefix='Marital')

# %%
df.head()
# Out:
#    age  Education                Job   relationship   race     sex  Hours  \
# 1   82          9    Exec-managerial  Not-in-family  White  Female     18
# 3   54          4  Machine-op-inspct      Unmarried  White  Female     40
# 4   41         10     Prof-specialty      Own-child  White  Female     40
# 5   34          9      Other-service      Unmarried  White  Female     45
# 6   38          6       Adm-clerical      Unmarried  White    Male     40
#
#          Country income  workclass_freq  Marital_Divorced  \
# 1  United-States  <=50K         0.73922                 0
# 3  United-States  <=50K         0.73922                 1
# 4  United-States  <=50K         0.73922                 0
# 5  United-States  <=50K         0.73922                 1
# 6  United-States  <=50K         0.73922                 0
#
#    Marital_Married-AF-spouse  Marital_Married-civ-spouse  \
# 1                          0                           0
# 3                          0                           0
# 4                          0                           0
# 5                          0                           0
# 6                          0                           0
#
#    Marital_Married-spouse-absent  Marital_Never-married  Marital_Separated  \
# 1                              0                      0                  0
# 3                              0                      0                  0
# 4                              0                      0                  1
# 5                              0                      0                  0
# 6                              0                      0                  1
#
#    Marital_Widowed
# 1                1
# 3                0
# 4                0
# 5                0
# 6                0

# %%
# for Job column using frequency encoding
location_freq = df["Job"].value_counts(normalize=True).to_dict()
df["job_freq"] = df["Job"].map(location_freq)
df.head()
# Out:
#    age  Education                Job   relationship   race     sex  Hours  \
# 1   82          9    Exec-managerial  Not-in-family  White  Female     18
# 3   54          4  Machine-op-inspct      Unmarried  White  Female     40
# 4   41         10     Prof-specialty      Own-child  White  Female     40
# 5   34          9      Other-service      Unmarried  White  Female     45
# 6   38          6       Adm-clerical      Unmarried  White    Male     40
#
#          Country income  workclass_freq  Marital_Divorced  \
# 1  United-States  <=50K         0.73922                 0
# 3  United-States  <=50K         0.73922                 1
# 4  United-States  <=50K         0.73922                 0
# 5  United-States  <=50K         0.73922                 1
# 6  United-States  <=50K         0.73922                 0
#
#    Marital_Married-AF-spouse  Marital_Married-civ-spouse  \
# 1                          0                           0
# 3                          0                           0
# 4                          0                           0
# 5                          0                           0
# 6                          0                           0
#
#    Marital_Married-spouse-absent  Marital_Never-married  Marital_Separated  \
# 1                              0                      0                  0
# 3                              0                      0                  0
# 4                              0                      0                  1
# 5                              0                      0                  0
# 6                              0                      0                  1
#
#    Marital_Widowed  job_freq
# 1                1  0.132413
# 3                0  0.065178
# 4                0  0.133939
# 5                0  0.106508
# 6                0  0.123325

# %%
df.drop(columns=["Job"], inplace=True)
df.head()
# Out:
#    age  Education   relationship   race     sex  Hours        Country income  \
# 1   82          9  Not-in-family  White  Female     18  United-States  <=50K
# 3   54          4      Unmarried  White  Female     40  United-States  <=50K
# 4   41         10      Own-child  White  Female     40  United-States  <=50K
# 5   34          9      Unmarried  White  Female     45  United-States  <=50K
# 6   38          6      Unmarried  White    Male     40  United-States  <=50K
#
#    workclass_freq  Marital_Divorced  Marital_Married-AF-spouse  \
# 1         0.73922                 0                          0
# 3         0.73922                 1                          0
# 4         0.73922                 0                          0
# 5         0.73922                 1                          0
# 6         0.73922                 0                          0
#
#    Marital_Married-civ-spouse  Marital_Married-spouse-absent  \
# 1                           0                              0
# 3                           0                              0
# 4                           0                              0
# 5                           0                              0
# 6                           0                              0
#
#    Marital_Never-married  Marital_Separated  Marital_Widowed  job_freq
# 1                      0                  0                1  0.132413
# 3                      0                  0                0  0.065178
# 4                      0                  1                0  0.133939
# 5                      0                  0                0  0.106508
# 6                      0                  1                0  0.123325

# %%
# For Relationship column, using hot encoding 

df['relationship'] = df['relationship'].astype('category')
df = pd.get_dummies(df, columns=['relationship'], prefix='relationship')

# %%
df.head()
# Out:
#    age  Education   race     sex  Hours        Country income  workclass_freq  \
# 1   82          9  White  Female     18  United-States  <=50K         0.73922
# 3   54          4  White  Female     40  United-States  <=50K         0.73922
# 4   41         10  White  Female     40  United-States  <=50K         0.73922
# 5   34          9  White  Female     45  United-States  <=50K         0.73922
# 6   38          6  White    Male     40  United-States  <=50K         0.73922
#
#    Marital_Divorced  Marital_Married-AF-spouse  ...  Marital_Never-married  \
# 1                 0                          0  ...                      0
# 3                 1                          0  ...                      0
# 4                 0                          0  ...                      0
# 5                 1                          0  ...                      0
# 6                 0                          0  ...                      0
#
#    Marital_Separated  Marital_Widowed  job_freq  relationship_Husband  \
# 1                  0                1  0.132413                     0
# 3                  0                0  0.065178                     0
# 4                  1                0  0.133939                     0
# 5                  0                0  0.106508                     0
# 6                  1                0  0.123325                     0
#
#    relationship_Not-in-family  relationship_Other-relative  \
# 1                           1                            0
# 3                           0                            0
# 4                           0                            0
# 5                           0                            0
# 6                           0                            0
#
#    relationship_Own-child  relationship_Unmarried  relationship_Wife
# 1                       0                       0                  0
# 3                       0                       1                  0
# 4                       1                       0                  0
# 5                       0                       1                  0
# 6                       0                       1                  0
#
# [5 rows x 22 columns]

# %%
# country - i am using one hot encoding as there are less number of unqiue of values 
df['Country'] = df['Country'].astype('category')
df = pd.get_dummies(df, columns=['Country'], prefix='Country')

# %%
df['Income'] = df['income'].apply(lambda x: 0 if x == '<=50K' else 1)

# %%
df.drop(columns=["income"],inplace=True)

# %%
df['race'] = df['race'].astype('category')
df = pd.get_dummies(df, columns=['race'], prefix='race')

# %%
df['sex'] = df['sex'].astype('category')
df = pd.get_dummies(df, columns=['sex'], prefix='sex')

# %%
df.head()
# Out:
#    age  Education  Hours  workclass_freq  Marital_Divorced  \
# 1   82          9     18         0.73922                 0
# 3   54          4     40         0.73922                 1
# 4   41         10     40         0.73922                 0
# 5   34          9     45         0.73922                 1
# 6   38          6     40         0.73922                 0
#
#    Marital_Married-AF-spouse  Marital_Married-civ-spouse  \
# 1                          0                           0
# 3                          0                           0
# 4                          0                           0
# 5                          0                           0
# 6                          0                           0
#
#    Marital_Married-spouse-absent  Marital_Never-married  Marital_Separated  \
# 1                              0                      0                  0
# 3                              0                      0                  0
# 4                              0                      0                  1
# 5                              0                      0                  0
# 6                              0                      0                  1
#
#    ...  Country_Vietnam  Country_Yugoslavia  Income  race_Amer-Indian-Eskimo  \
# 1  ...                0                   0       0                        0
# 3  ...                0                   0       0                        0
# 4  ...                0                   0       0                        0
# 5  ...                0                   0       0                        0
# 6  ...                0                   0       0                        0
#
#    race_Asian-Pac-Islander  race_Black  race_Other  race_White  sex_Female  \
# 1                        0           0           0           1           1
# 3                        0           0           0           1           1
# 4                        0           0           0           1           1
# 5                        0           0           0           1           1
# 6                        0           0           0           1           0
#
#    sex_Male
# 1         0
# 3         0
# 4         0
# 5         0
# 6         1
#
# [5 rows x 67 columns]

# %%
# normalizing hours and age column using min - max scaling

from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
age_values = df['age'].values.reshape(-1, 1)
Hours_values = df['Hours'].values.reshape(-1, 1)
df['age_normalized'] = scaler.fit_transform(age_values)
df['Hours_normalized'] = scaler.fit_transform(Hours_values)

# %%
df.drop(columns=["age","Hours"],inplace=True)

# %%
df["Income"]=df["Income"].astype("int")
df["Education"]=df["Education"].astype("int")

# %%
df.head()
# Out:
#    Education  workclass_freq  Marital_Divorced  Marital_Married-AF-spouse  \
# 1          9         0.73922                 0                          0
# 3          4         0.73922                 1                          0
# 4         10         0.73922                 0                          0
# 5          9         0.73922                 1                          0
# 6          6         0.73922                 0                          0
#
#    Marital_Married-civ-spouse  Marital_Married-spouse-absent  \
# 1                           0                              0
# 3                           0                              0
# 4                           0                              0
# 5                           0                              0
# 6                           0                              0
#
#    Marital_Never-married  Marital_Separated  Marital_Widowed  job_freq  ...  \
# 1                      0                  0                1  0.132413  ...
# 3                      0                  0                0  0.065178  ...
# 4                      0                  1                0  0.133939  ...
# 5                      0                  0                0  0.106508  ...
# 6                      0                  1                0  0.123325  ...
#
#    Income  race_Amer-Indian-Eskimo  race_Asian-Pac-Islander  race_Black  \
# 1       0                        0                        0           0
# 3       0                        0                        0           0
# 4       0                        0                        0           0
# 5       0                        0                        0           0
# 6       0                        0                        0           0
#
#    race_Other  race_White  sex_Female  sex_Male  age_normalized  \
# 1           0           1           1         0        0.890411
# 3           0           1           1         0        0.506849
# 4           0           1           1         0        0.328767
# 5           0           1           1         0        0.232877
# 6           0           1           0         1        0.287671
#
#    Hours_normalized
# 1          0.173469
# 3          0.397959
# 4          0.397959
# 5          0.448980
# 6          0.397959
#
# [5 rows x 67 columns]

# %%
df.shape
# Out:
# (30148, 67)

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
X = df.drop(columns=["Income"])
y = df['Income']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=int(max(y)))

# I have used GridSearchCV on my local machine and best parameters obtained from GridSearchCV are listed below
best_params = {
    'n_estimators': 300,
    'max_depth': 20,
    'min_samples_split': 10,
    'min_samples_leaf': 1
}

# Initialize the RandomForestClassifier with the best parameters
best_rf_classifier = RandomForestClassifier(**best_params)

# Train the classifier
best_rf_classifier.fit(X_train, y_train)

# Make predictions
y_pred = best_rf_classifier.predict(X_test)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.8403537866224433
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90      6811
#            1       0.73      0.56      0.64      2234
#
#     accuracy                           0.84      9045
#    macro avg       0.80      0.75      0.77      9045
# weighted avg       0.83      0.84      0.83      9045
#
#
# Confusion Matrix:
#  [[6339  472]
#  [ 972 1262]]
