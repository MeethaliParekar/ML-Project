# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Wine.csv')
df
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
#  13  Customer_Segment      178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
df.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# Customer_Segment        0
# dtype: int64

# %% [markdown]
# Checking for outliers using boxplot

# %%
df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 1
# ...

# %%
def boxplots(col):
    plt.figure(figsize=(5,5))
    sns.boxplot(df,x=col,palette ='crest')
    plt.show()
for i in list(df.columns):
    boxplots(i)

# %% [markdown]
# Using displot

# %%
def displots(col):
    plt.figure(figsize=(5,5))
    sns.displot(df[col], kde=True,color='red')
    sns.set(style = 'dark')
    plt.show()
for i in list(df.columns):
    displots(i)

# %% [markdown]
# # Encoding concept

# %% [markdown]
# #Target variable is Customer_Segment.

# %%
new_df=df.copy()
new_df['Customer_Segment']=new_df['Customer_Segment'].astype('category')
new_df['Customer_Segment']=new_df['Customer_Segment'].cat.codes

# %%
new_df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 0
# ...

# %%
## Splitting dataset into dependant and independant variable.
x= new_df.drop(['Customer_Segment'], axis=1)
x.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# ...

# %%
y=new_df['Customer_Segment']
pd.DataFrame(y)
# Out:
#      Customer_Segment
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ..                ...
# 173                 2
# 174                 2
# 175                 2
# 176                 2
# 177                 2
#
# [178 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
fs_x=std.fit_transform(x)
pd.DataFrame(fs_x)
# Out:
#            0         1         2         3         4         5         6   \
# 0    1.518613 -0.562250  0.232053 -1.169593  1.913905  0.808997  1.034819
# 1    0.246290 -0.499413 -0.827996 -2.490847  0.018145  0.568648  0.733629
# 2    0.196879  0.021231  1.109334 -0.268738  0.088358  0.808997  1.215533
# 3    1.691550 -0.346811  0.487926 -0.809251  0.930918  2.491446  1.466525
# 4    0.295700  0.227694  1.840403  0.451946  1.281985  0.808997  0.663351
# ..        ...       ...       ...       ...       ...       ...       ...
# 173  0.876275  2.974543  0.305159  0.301803 -0.332922 -0.985614 -1.424900
# 174  0.493343  1.412609  0.414820  1.052516  0.158572 -0.793334 -1.284344
# 175  0.332758  1.744744 -0.389355  0.151661  1.422412 -1.129824 -1.344582
# 176  0.209232  0.227694  0.012732  0.151661  1.422412 -1.033684 -1.354622
# 177  1.395086  1.583165  1.365208  1.502943 -0.262708 -0.392751 -1.274305
#
#            7         8         9         10        11        12
# ...

# %% [markdown]
# ##Imbalance data treatment
#  It is the most important data pre processing step in classification Modelling.

# %%
new_df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 0
# ...

# %%
new_df['Customer_Segment'].value_counts()
# Out:
# 1    71
# 0    59
# 2    48
# Name: Customer_Segment, dtype: int64

# %%
plt.figure(figsize=(5,5))
ax=sns.barplot(x=new_df['Customer_Segment'].value_counts().index, y=new_df['Customer_Segment'].value_counts().values, data=new_df,palette='plasma')
for i in ax.containers:
    ax.bar_label(i)
plt.show()

# %%
new_df['Customer_Segment'].value_counts()/len(new_df*100)
# Out:
# 1    0.398876
# 0    0.331461
# 2    0.269663
# Name: Customer_Segment, dtype: float64

# %%
plt.figure(figsize=(7,7),dpi=100)
plt.pie(new_df['Customer_Segment'].value_counts()/len(new_df*100),
       labels=new_df['Customer_Segment'].value_counts().index,
       autopct='%.3f%%',shadow=True,explode=[0.1 for i in range(3)],colors=sns.color_palette('Set1'))
plt.show()

# %% [markdown]
# It is a balanced dataset.(Minority class *2>Majority Class)

# %% [markdown]
# # Train Test Split Method

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=43)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((133, 13), (45, 13), (133,), (45,))

# %% [markdown]
# Building a Multiclass Classification Model

# %% [markdown]
# # Approach 1: Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
lr_model=LogisticRegression(multi_class='multinomial')
lr_model.fit(x_train,y_train)
# Out:
# LogisticRegression(multi_class='multinomial')

# %%
y_train_pred=lr_model.predict(x_train)
y_test_pred=lr_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report

# %%
train_accuracylr=accuracy_score(y_train,y_train_pred)
test_accuracylr=accuracy_score(y_test,y_test_pred)

# %%
print('Train Accuracy LR:',accuracy_score(y_train,y_train_pred))
print('Test Accuracy LR:',accuracy_score(y_test,y_test_pred))
# Out:
# Train Accuracy LR: 0.9548872180451128
# Test Accuracy LR: 0.9777777777777777

# %%
print('Train Data LR:',confusion_matrix(y_train,y_train_pred))
print('Test Data LR:',confusion_matrix(y_test,y_test_pred))
# Out:
# Train Data LR: [[37  3  0]
#  [ 1 53  2]
#  [ 0  0 37]]
# Test Data LR: [[19  0  0]
#  [ 1 14  0]
#  [ 0  0 11]]

# %%
print('Train Data LR:',classification_report(y_train,y_train_pred))
print('Test Data LR:',classification_report(y_test,y_test_pred))
# Out:
# Train Data LR:               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95        40
#            1       0.95      0.95      0.95        56
#            2       0.95      1.00      0.97        37
#
#     accuracy                           0.95       133
#    macro avg       0.96      0.96      0.96       133
# weighted avg       0.96      0.95      0.95       133
#
# Test Data LR:               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        19
#            1       1.00      0.93      0.97        15
#            2       1.00      1.00      1.00        11
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
Labels=['Customer_Segment1','Customer_Segment2','Customer_Segment3']
conf_matrix_1=confusion_matrix(y_train,y_train_pred)
conf_matrix_2=confusion_matrix(y_test,y_test_pred)
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
sns.heatmap(conf_matrix_1,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='cividis')
plt.title('TRAIN DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
        
        
plt.subplot(1,2,2)
sns.heatmap(conf_matrix_2,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='cividis')
plt.title('TEST DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
plt.show()

# %% [markdown]
# # Approach 2 : Random Forest Method

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model=RandomForestClassifier()
rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_train_pred=rf_model.predict(x_train)
y_test_pred=rf_model.predict(x_test)

# %%
print('Train Accuracy RF:',accuracy_score(y_train,y_train_pred))
print('Test Accuracy RF:',accuracy_score(y_test,y_test_pred))
# Out:
# Train Accuracy RF: 1.0
# Test Accuracy RF: 1.0

# %%
print('Train Data RF:',confusion_matrix(y_train,y_train_pred))
print('Test Data RF:',confusion_matrix(y_test,y_test_pred))
# Out:
# Train Data RF: [[40  0  0]
#  [ 0 56  0]
#  [ 0  0 37]]
# Test Data RF: [[19  0  0]
#  [ 0 15  0]
#  [ 0  0 11]]

# %%
Labels=['Customer_Segment1','Customer_Segment2','Customer_Segment3']
conf_matrix_1=confusion_matrix(y_train,y_train_pred)
conf_matrix_2=confusion_matrix(y_test,y_test_pred)
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
sns.heatmap(conf_matrix_1,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='viridis')
plt.title('TRAIN DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
        
        
plt.subplot(1,2,2)
sns.heatmap(conf_matrix_2,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='viridis')
plt.title('TEST DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
plt.show()

# %%
print('Train Data RF:',classification_report(y_train,y_train_pred))
print('Test Data RF:',classification_report(y_test,y_test_pred))
# Out:
# Train Data RF:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        40
#            1       1.00      1.00      1.00        56
#            2       1.00      1.00      1.00        37
#
#     accuracy                           1.00       133
#    macro avg       1.00      1.00      1.00       133
# weighted avg       1.00      1.00      1.00       133
#
# Test Data RF:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        15
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# # Cross Validation score to resolve Overfitting Problem(Train data -100% = Overfit)

# %%
from sklearn.model_selection import cross_val_score

train_accuracy_rf=cross_val_score(rf_model,x_train,y_train,cv=10).mean()
train_accuracy_rf=cross_val_score(rf_model,x_test,y_test,cv=10).mean()

print('TRAINING SCORE RF:',cross_val_score(rf_model,x_train,y_train,cv=10).mean())
print('TESTING SCORE RF:',cross_val_score(rf_model,x_test,y_test,cv=10).mean())
# Out:
# TRAINING SCORE RF: 0.9846153846153847
# TESTING SCORE RF: 0.9800000000000001

# %% [markdown]
# # Overfitting problem is treated, getting good accuracy.

# %% [markdown]
# # Using criterion 'Gini'

# %%
from sklearn.tree import DecisionTreeClassifier
dtc_model1=DecisionTreeClassifier(criterion='gini')
dtc_model1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_train_predict=dtc_model1.predict(x_train)
y_test_predict=dtc_model1.predict(x_test)

# %%
print('Train Accuracy DTC:',accuracy_score(y_train,y_train_pred))
print('Test Accuracy DTC:',accuracy_score(y_test,y_test_pred))
# Out:
# Train Accuracy DTC: 1.0
# Test Accuracy DTC: 1.0

# %%
print('Train Data DTC:',confusion_matrix(y_train,y_train_pred))
print('Test Data DTC:',confusion_matrix(y_test,y_test_pred))
# Out:
# Train Data DTC: [[40  0  0]
#  [ 0 56  0]
#  [ 0  0 37]]
# Test Data DTC: [[19  0  0]
#  [ 0 15  0]
#  [ 0  0 11]]

# %%
print('Train Data DTC:',classification_report(y_train,y_train_pred))
print('Test Data DTC:',classification_report(y_test,y_test_pred))
# Out:
# Train Data DTC:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        40
#            1       1.00      1.00      1.00        56
#            2       1.00      1.00      1.00        37
#
#     accuracy                           1.00       133
#    macro avg       1.00      1.00      1.00       133
# weighted avg       1.00      1.00      1.00       133
#
# Test Data DTC:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        15
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
Labels=['Customer_Segment1','Customer_Segment2','Customer_Segment3']
conf_matrix_1=confusion_matrix(y_train,y_train_pred)
conf_matrix_2=confusion_matrix(y_test,y_test_pred)
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
sns.heatmap(conf_matrix_1,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='plasma')
plt.title('TRAIN DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
        
        
plt.subplot(1,2,2)
sns.heatmap(conf_matrix_2,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='plasma')
plt.title('TEST DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
plt.show()

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10,10))
plot_tree(dtc_model1,filled=True,feature_names=x.columns)
plt.show()

# %% [markdown]
# # Using Criterion 'Entropy'

# %%
dtc_model2=DecisionTreeClassifier(criterion='gini')
dtc_model2.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_train_pred=dtc_model2.predict(x_train)
y_test_pred=dtc_model2.predict(x_test)

# %%
print('Train Accuracy DTCE:',accuracy_score(y_train,y_train_pred))
print('Test Accuracy DTCE:',accuracy_score(y_test,y_test_pred))
# Out:
# Train Accuracy DTCE: 1.0
# Test Accuracy DTCE: 0.9555555555555556

# %%
print('Train Data DTCE:',confusion_matrix(y_train,y_train_pred))
print('Test Data DTCE:',confusion_matrix(y_test,y_test_pred))
# Out:
# Train Data DTCE: [[40  0  0]
#  [ 0 56  0]
#  [ 0  0 37]]
# Test Data DTCE: [[18  1  0]
#  [ 0 15  0]
#  [ 0  1 10]]

# %%
print('Train Data DTCE:',classification_report(y_train,y_train_pred))
print('Test Data DTCE:',classification_report(y_test,y_test_pred))
# Out:
# Train Data DTCE:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        40
#            1       1.00      1.00      1.00        56
#            2       1.00      1.00      1.00        37
#
#     accuracy                           1.00       133
#    macro avg       1.00      1.00      1.00       133
# weighted avg       1.00      1.00      1.00       133
#
# Test Data DTCE:               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97        19
#            1       0.88      1.00      0.94        15
#            2       1.00      0.91      0.95        11
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %%
Labels=['Customer_Segment1','Customer_Segment2','Customer_Segment3']
conf_matrix_1=confusion_matrix(y_train,y_train_pred)
conf_matrix_2=confusion_matrix(y_test,y_test_pred)
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
sns.heatmap(conf_matrix_1,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='plasma')
plt.title('TRAIN DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
        
        
plt.subplot(1,2,2)
sns.heatmap(conf_matrix_2,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='plasma')
plt.title('TEST DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
plt.show()

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10,10))
plot_tree(dtc_model2,filled=True,feature_names=x.columns)
plt.show()

# %%
# Checking the feature importance value in this model.

# %%
dtc_model1.feature_importances_
# Out:
# array([0.        , 0.        , 0.02250345, 0.01968232, 0.        ,
#        0.        , 0.39939675, 0.        , 0.        , 0.41513183,
#        0.02235843, 0.02162096, 0.09930625])

# %%
DTC_MODEL=pd.DataFrame()

# %%
DTC_MODEL['Features']=x.columns

# %%
DTC_MODEL['Feature Importance Value']=dtc_model1.feature_importances_

# %%
DTC_MODEL=DTC_MODEL.sort_values(by='Feature Importance Value',ascending=False)
DTC_MODEL
# Out:
#                 Features  Feature Importance Value
# 9        Color_Intensity                  0.415132
# 6             Flavanoids                  0.399397
# 12               Proline                  0.099306
# 2                    Ash                  0.022503
# 10                   Hue                  0.022358
# 11                 OD280                  0.021621
# 3           Ash_Alcanity                  0.019682
# 0                Alcohol                  0.000000
# 1             Malic_Acid                  0.000000
# 4              Magnesium                  0.000000
# 5          Total_Phenols                  0.000000
# 7   Nonflavanoid_Phenols                  0.000000
# 8        Proanthocyanins                  0.000000

# %% [markdown]
# # Plotting Barplot

# %%
plt.figure(figsize=(18,8))
ax=sns.barplot(x='Features', y='Feature Importance Value',data=DTC_MODEL,palette='hls')
for i in ax.containers:
    ax.bar_label(i)
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
error_rate = []

for i in range(1,40):
     knn_model = KNeighborsClassifier(n_neighbors=i)
     knn_model.fit(x_train, y_train)
     y_test_pred = knn_model.predict(x_test)
     error_rate.append(np.mean(y_test_pred !=y_test))

# %%
error_rate
# Out:
# [0.2222222222222222,
#  0.3333333333333333,
#  0.24444444444444444,
#  0.2,
#  0.2,
#  0.17777777777777778,
#  0.17777777777777778,
#  0.2222222222222222,
#  0.2,
#  0.26666666666666666,
#  0.2222222222222222,
#  0.2222222222222222,
#  0.2222222222222222,
#  0.2,
#  0.17777777777777778,
#  0.17777777777777778,
#  0.17777777777777778,
#  0.2,
#  0.17777777777777778,
#  0.15555555555555556,
#  0.15555555555555556,
#  0.17777777777777778,
#  0.17777777777777778,
#  0.2,
#  0.17777777777777778,
#  0.17777777777777778,
#  0.15555555555555556,
#  0.17777777777777778,
#  0.17777777777777778,
#  0.2,
#  0.2,
#  0.17777777777777778,
#  0.15555555555555556,
#  0.15555555555555556,
#  0.15555555555555556,
#  0.15555555555555556,
#  0.15555555555555556,
#  0.17777777777777778,
#  0.17777777777777778]

# %%
knn_model=KNeighborsClassifier(n_neighbors=3)
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_train_pred=knn_model.predict(x_train)
y_test_pred=knn_model.predict(x_test)

# %%
train_accuracy_knn=accuracy_score(y_train,y_train_pred)
test_accuracy_knn=accuracy_score(y_test,y_test_pred)

# %%
print('TRAIN ACCURACY:',accuracy_score(y_train,y_train_pred))
print()
print('TEST ACCURACY:',accuracy_score(y_test,y_test_pred))
# Out:
# TRAIN ACCURACY: 0.8571428571428571
#
# TEST ACCURACY: 0.7555555555555555

# %%
print('Train Data KNN:',confusion_matrix(y_train,y_train_pred))
print('Test Data KNN:',confusion_matrix(y_test,y_test_pred))
# Out:
# Train Data KNN: [[37  0  3]
#  [ 4 45  7]
#  [ 1  4 32]]
# Test Data KNN: [[17  1  1]
#  [ 2 10  3]
#  [ 3  1  7]]

# %%
print('Train Data KNN:',classification_report(y_train,y_train_pred))
print('Test Data KNN:',classification_report(y_test,y_test_pred))
# Out:
# Train Data KNN:               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90        40
#            1       0.92      0.80      0.86        56
#            2       0.76      0.86      0.81        37
#
#     accuracy                           0.86       133
#    macro avg       0.85      0.86      0.86       133
# weighted avg       0.86      0.86      0.86       133
#
# Test Data KNN:               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83        19
#            1       0.83      0.67      0.74        15
#            2       0.64      0.64      0.64        11
#
#     accuracy                           0.76        45
#    macro avg       0.75      0.73      0.74        45
# weighted avg       0.76      0.76      0.75        45

# %%
Labels=['Customer_Segment1','Customer_Segment2','Customer_Segment3']
conf_matrix_1=confusion_matrix(y_train,y_train_pred)
conf_matrix_2=confusion_matrix(y_test,y_test_pred)
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
sns.heatmap(conf_matrix_1,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='inferno')
plt.title('TRAIN DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
        
        
plt.subplot(1,2,2)
sns.heatmap(conf_matrix_2,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='inferno')
plt.title('TEST DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
plt.show()

# %% [markdown]
# plt.figure(figsize=(14,14))
# plt.plot(range(1,40),error_rate, color='green', linestyle='dashed', marker='*',
#          markerfacecolor='red', markersize=10)
# plt.title("Error rate VS Hyperparam_value")
# plt.xlabel("K_HyperParam_value")
# plt.ylabel("Error Rate")
# plt.show()

# %% [markdown]
# ### Approach Gradient Boosting Method.

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc_model=GradientBoostingClassifier()
gbc_model.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_train_pred=gbc_model.predict(x_train)
y_test_pred=gbc_model.predict(x_test)

# %%
print('TRAIN ACCURACY GB:',accuracy_score(y_train,y_train_pred))
print()
print('TEST ACCURACY GB:',accuracy_score(y_test,y_test_pred))
# Out:
# TRAIN ACCURACY GB: 1.0
#
# TEST ACCURACY GB: 1.0

# %% [markdown]
# ## Cross Validation Score

# %%
train_accuracy_gb=cross_val_score(gbc_model,x_train,y_train,cv=10).mean()
test_accuracy_gb=cross_val_score(gbc_model,x_test,y_test,cv=10).mean()

# %%
print('TRAIN ACCURACY GB:',cross_val_score(gbc_model,x_train,y_train,cv=10).mean())
print()
print('TEST ACCURACY GB:',cross_val_score(gbc_model,x_test,y_test,cv=10).mean())
# Out:
# TRAIN ACCURACY GB: 0.934065934065934
#
# TEST ACCURACY GB: 0.89

# %%
print('Train Data GB:',confusion_matrix(y_train,y_train_pred))
print('Test Data GB:',confusion_matrix(y_test,y_test_pred))
# Out:
# Train Data GB: [[40  0  0]
#  [ 0 56  0]
#  [ 0  0 37]]
# Test Data GB: [[19  0  0]
#  [ 0 15  0]
#  [ 0  0 11]]

# %%
print('Train Data GB:',classification_report(y_train,y_train_pred))
print('Test Data GB:',classification_report(y_test,y_test_pred))
# Out:
# Train Data GB:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        40
#            1       1.00      1.00      1.00        56
#            2       1.00      1.00      1.00        37
#
#     accuracy                           1.00       133
#    macro avg       1.00      1.00      1.00       133
# weighted avg       1.00      1.00      1.00       133
#
# Test Data GB:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        15
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
Labels=['Customer_Segment1','Customer_Segment2','Customer_Segment3']
conf_matrix_1=confusion_matrix(y_train,y_train_pred)
conf_matrix_2=confusion_matrix(y_test,y_test_pred)
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
sns.heatmap(conf_matrix_1,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='rainbow')
plt.title('TRAIN DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
        
        
plt.subplot(1,2,2)
sns.heatmap(conf_matrix_2,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='rainbow')
plt.title('TEST DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
plt.show()

# %% [markdown]
# ## Approach ADA Boost Method

# %%
from sklearn.ensemble import AdaBoostClassifier
abc_model=AdaBoostClassifier()
abc_model.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_train_pred=abc_model.predict(x_train)
y_test_pred=abc_model.predict(x_test)

# %%
print('TRAIN ACCURACY AB:',accuracy_score(y_train,y_train_predict))
print()
print('TEST ACCURACY AB:',accuracy_score(y_test,y_test_pred))
# Out:
# TRAIN ACCURACY AB: 1.0
#
# TEST ACCURACY AB: 0.8666666666666667

# %%
train_accuracy_ab=cross_val_score(abc_model,x_train,y_train,cv=10).mean()
test_accuracy_ab=cross_val_score(abc_model, x_test,y_test,cv=10).mean()

# %%
print('Train accuracy ABC:',cross_val_score(abc_model,x_train,y_train,cv=10).mean())
print()
print('Test accuracy ABC:',cross_val_score(abc_model, x_test,y_test,cv=10).mean())
# Out:
# Train accuracy ABC: 0.8950549450549451
#
# Test accuracy ABC: 0.865

# %%
print('Train Data ABC:',confusion_matrix(y_train,y_train_pred))
print('Test Data ABC:',confusion_matrix(y_test,y_test_pred))
# Out:
# Train Data ABC: [[38  2  0]
#  [ 7 49  0]
#  [ 0  0 37]]
# Test Data ABC: [[17  2  0]
#  [ 4 11  0]
#  [ 0  0 11]]

# %%
print('Train Data ABC:',classification_report(y_train,y_train_pred))
print('Test Data ABC:',classification_report(y_test,y_test_pred))
# Out:
# Train Data ABC:               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89        40
#            1       0.96      0.88      0.92        56
#            2       1.00      1.00      1.00        37
#
#     accuracy                           0.93       133
#    macro avg       0.94      0.94      0.94       133
# weighted avg       0.94      0.93      0.93       133
#
# Test Data ABC:               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85        19
#            1       0.85      0.73      0.79        15
#            2       1.00      1.00      1.00        11
#
#     accuracy                           0.87        45
#    macro avg       0.89      0.88      0.88        45
# weighted avg       0.87      0.87      0.87        45

# %%
Labels=['Customer_Segment1','Customer_Segment2','Customer_Segment3']
conf_matrix_1=confusion_matrix(y_train,y_train_pred)
conf_matrix_2=confusion_matrix(y_test,y_test_pred)
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
sns.heatmap(conf_matrix_1,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='flare')
plt.title('TRAIN DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
        
        
plt.subplot(1,2,2)
sns.heatmap(conf_matrix_2,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='flare')
plt.title('TEST DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
plt.show()

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier
xgb_model=XGBClassifier()
xgb_model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_train_pred=xgb_model.predict(x_train)
y_test_pred=xgb_model.predict(x_test)

# %%
print('TRAIN ACCURACY SCORE XGB:', accuracy_score(y_train,y_train_pred))
print()
print('TEST ACCURACY SCORE XGB:', accuracy_score(y_test,y_test_pred))
# Out:
# TRAIN ACCURACY SCORE XGB: 1.0
#
# TEST ACCURACY SCORE XGB: 1.0

# %%
train_accuracy_xgb=cross_val_score(xgb_model,x_train,y_train,cv=10).mean()
test_accuract_xgb=cross_val_score(xgb_model,x_test,y_test,cv=10).mean()

# %%
print('TRAIN ACCURACY XGB:',cross_val_score(xgb_model,x_train,y_train,cv=10).mean())
print()
print('TEST ACCURACY XGB:',cross_val_score(xgb_model,x_test,y_test,cv=10).mean())
# Out:
# TRAIN ACCURACY XGB: 0.9472527472527472
#
# TEST ACCURACY XGB: 0.93

# %%
print('TRAIN ACCURACY SCORE XGB:', confusion_matrix(y_train,y_train_pred))
print()
print('TEST ACCURACY SCORE XGB:', confusion_matrix(y_test,y_test_pred))
# Out:
# TRAIN ACCURACY SCORE XGB: [[40  0  0]
#  [ 0 56  0]
#  [ 0  0 37]]
#
# TEST ACCURACY SCORE XGB: [[19  0  0]
#  [ 0 15  0]
#  [ 0  0 11]]

# %%
print('TRAIN ACCURACY SCORE XGB:',classification_report(y_train,y_train_pred))
print()
print('TEST ACCURACY SCORE XGB:',classification_report(y_test,y_test_pred))
# Out:
# TRAIN ACCURACY SCORE XGB:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        40
#            1       1.00      1.00      1.00        56
#            2       1.00      1.00      1.00        37
#
#     accuracy                           1.00       133
#    macro avg       1.00      1.00      1.00       133
# weighted avg       1.00      1.00      1.00       133
#
#
# TEST ACCURACY SCORE XGB:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        15
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
Labels=['Customer_Segment1','Customer_Segment2','Customer_Segment3']
conf_matrix_1=confusion_matrix(y_train,y_train_pred)
conf_matrix_2=confusion_matrix(y_test,y_test_pred)
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
sns.heatmap(conf_matrix_1,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='rocket')
plt.title('TRAIN DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
        
        
plt.subplot(1,2,2)
sns.heatmap(conf_matrix_2,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='rocket')
plt.title('TEST DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
plt.show()

# %% [markdown]
# # Approach Naives-Bayes - Gaussian NB Method

# %%
from sklearn.naive_bayes import GaussianNB
nbg_model=GaussianNB()
nbg_model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_train_pred=nbg_model.predict(x_train)
y_test_pred=nbg_model.predict(x_test)

# %%
train_accuracy_gauss=accuracy_score(y_train,y_train_pred)
test_accuracy_gauss=accuracy_score(y_test,y_test_pred)

# %%
print('TRAIN ACCURACY NBG:',accuracy_score(y_train,y_train_pred))
print()
print('TEST ACCURACY NBG:',accuracy_score(y_test,y_test_pred))
# Out:
# TRAIN ACCURACY NBG: 0.9699248120300752
#
# TEST ACCURACY NBG: 1.0

# %%
print('TRAIN ACCURACY NBG:',confusion_matrix(y_train,y_train_pred))
print()
print('TEST ACCURACY NBG:',confusion_matrix(y_test,y_test_pred))
# Out:
# TRAIN ACCURACY NBG: [[37  3  0]
#  [ 0 55  1]
#  [ 0  0 37]]
#
# TEST ACCURACY NBG: [[19  0  0]
#  [ 0 15  0]
#  [ 0  0 11]]

# %%
print('TRAIN ACCURACY NBG:',classification_report(y_train,y_train_pred))
print()
print('TEST ACCURACY NBG:',classification_report(y_test,y_test_pred))
# Out:
# TRAIN ACCURACY NBG:               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96        40
#            1       0.95      0.98      0.96        56
#            2       0.97      1.00      0.99        37
#
#     accuracy                           0.97       133
#    macro avg       0.97      0.97      0.97       133
# weighted avg       0.97      0.97      0.97       133
#
#
# TEST ACCURACY NBG:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        15
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
Labels=['Customer_Segment1','Customer_Segment2','Customer_Segment3']
conf_matrix1=confusion_matrix(y_train,y_train_pred)
conf_matrix2=confusion_matrix(y_test,y_test_pred)
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
sns.heatmap(conf_matrix1,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='YlOrBr')
plt.title('Train Data')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')

plt.subplot(1,2,2)
sns.heatmap(conf_matrix2,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='YlOrBr')
plt.title('Test Data')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
plt.show()

# %% [markdown]
# # Approach (Naive_Bayes -Bernoulli NB Method)

# %%
from sklearn.naive_bayes import BernoulliNB
nbnb_model=BernoulliNB()
nbnb_model.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
y_train_pred=nbnb_model.predict(x_train)
y_test_pred=nbnb_model.predict(x_test)

# %%
print('TRAIN ACCURACY BER:', accuracy_score(y_train,y_train_pred))
print()
print('TEST ACCURACY BER:', accuracy_score(y_test,y_test_pred))
# Out:
# TRAIN ACCURACY BER: 0.42105263157894735
#
# TEST ACCURACY BER: 0.3333333333333333

# %%
print('TRAIN ACCURACY:', confusion_matrix(y_train,y_train_pred))
print()
print('TEST ACCURACY:', confusion_matrix(y_test,y_test_pred))
# Out:
# TRAIN ACCURACY: [[ 0 40  0]
#  [ 0 56  0]
#  [ 0 37  0]]
#
# TEST ACCURACY: [[ 0 19  0]
#  [ 0 15  0]
#  [ 0 11  0]]

# %%
print('TRAIN ACCURACY:', classification_report(y_train,y_train_pred))
print()
print('TEST ACCURACY:', classification_report(y_test,y_test_pred))
# Out:
# TRAIN ACCURACY:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        40
#            1       0.42      1.00      0.59        56
#            2       0.00      0.00      0.00        37
#
#     accuracy                           0.42       133
#    macro avg       0.14      0.33      0.20       133
# weighted avg       0.18      0.42      0.25       133
#
#
# TEST ACCURACY:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        19
#            1       0.33      1.00      0.50        15
#            2       0.00      0.00      0.00        11
#
#     accuracy                           0.33        45
#    macro avg       0.11      0.33      0.17        45
# weighted avg       0.11      0.33      0.17        45

# %%
Labels=['Customer_Segment1','Customer_Segment2','Customer_Segment3']
conf_matrix1=confusion_matrix(y_train,y_train_pred)
conf_matrix2=confusion_matrix(y_test,y_test_pred)
sns.heatmap(conf_matrix1,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='icefire')
plt.figure(figsize=(13,5))
plt.subplot(1,2,2)
plt.title('TRAIN DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')

plt.subplot(1,2,2)
sns.heatmap(conf_matrix2,xticklabels=Labels,yticklabels=Labels,annot=True,cmap='icefire')
plt.title('TEST DATA')
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')

plt.show()

# %% [markdown]
# # Creating a Dataframe(To show the final evaluated model score)

# %%
List_1=['LogisticRegression','RandomForestClassifier','DecisionTreeClassifier','KNeighborsClassifier',
        'GradientBoostingClassifier','AdaBoostClassifier','XGBClassifier','GaussianNB','BernoulliNB']

# %%
List_2=['train_accuracy_lr','train_accuracy_rf','train_accuracy_DTC','train_accuracy_knn','train_accuracy_gb',
'train_accuracy_ab','train_accuracy_xgb','train_accuracy_gauss','train_accuracy_berno']

# %%
List_3=['test_accuracylr','Test Accuracy RF','Test Accuracy DTC','test_accuracy_knn','TEST ACCURACY GB',
        'TEST ACCURACY AB','TEST ACCURACY SCORE XGB','test_accuracy_gauss','TEST ACCURACY BER']

# %%
EVALUATED_MODEL=pd.DataFrame()

# %%
EVALUATED_MODEL['Algorithms']=List_1

# %%
EVALUATED_MODEL['Training Accuracy Score']=List_2

# %%
EVALUATED_MODEL['Test Accuracy Score']=List_3

# %%
EVALUATED_MODEL
# Out:
#                    Algorithms Training Accuracy Score      Test Accuracy Score
# 0          LogisticRegression       train_accuracy_lr          test_accuracylr
# 1      RandomForestClassifier       train_accuracy_rf         Test Accuracy RF
# 2      DecisionTreeClassifier      train_accuracy_DTC        Test Accuracy DTC
# 3        KNeighborsClassifier      train_accuracy_knn        test_accuracy_knn
# 4  GradientBoostingClassifier       train_accuracy_gb         TEST ACCURACY GB
# 5          AdaBoostClassifier       train_accuracy_ab         TEST ACCURACY AB
# 6               XGBClassifier      train_accuracy_xgb  TEST ACCURACY SCORE XGB
# 7                  GaussianNB    train_accuracy_gauss      test_accuracy_gauss
# 8                 BernoulliNB    train_accuracy_berno        TEST ACCURACY BER
